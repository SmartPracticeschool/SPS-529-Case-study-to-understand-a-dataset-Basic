# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as mp

# %%
import os

# %%
df=pd.read_csv("C:/Users/LAKSHMI/Documents/boston_data.csv")

# %%
df
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0     0.15876   0.0  10.81   0.0  0.413  5.961   17.5  5.2873   4.0  305.0
# 1     0.10328  25.0   5.13   0.0  0.453  5.927   47.2  6.9320   8.0  284.0
# 2     0.34940   0.0   9.90   0.0  0.544  5.972   76.7  3.1025   4.0  304.0
# 3     2.73397   0.0  19.58   0.0  0.871  5.597   94.9  1.5257   5.0  403.0
# 4     0.04337  21.0   5.64   0.0  0.439  6.115   63.0  6.8147   4.0  243.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 399   9.32909   0.0  18.10   0.0  0.713  6.185   98.7  2.2616  24.0  666.0
# 400  51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 401   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 402   0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876   2.0  313.0
# 403   0.08244  30.0   4.93   0.0  0.428  6.481   18.5  6.1899   6.0  300.0
#
#      ptratio   black  lstat  medv
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox         rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.00000
# mean     3.730912   10.509901   11.189901    0.069307    0.556710    6.30145
# std      8.943922   22.053733    6.814909    0.254290    0.117321    0.67583
# min      0.006320    0.000000    0.460000    0.000000    0.392000    3.56100
# 25%      0.082382    0.000000    5.190000    0.000000    0.453000    5.90275
# 50%      0.253715    0.000000    9.795000    0.000000    0.538000    6.23050
# 75%      4.053158   12.500000   18.100000    0.000000    0.631000    6.62925
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.78000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.601733    3.799666    9.836634  411.688119   18.444554  355.068243
# ...

# %%
df_binary=df[['crim','lstat']]

# %%
df_binary.columns=['crime','stat']

# %%
df_binary.head()
# Out:
#      crime   stat
# 0  0.15876   9.88
# 1  0.10328   9.22
# 2  0.34940   9.97
# 3  2.73397  21.45
# 4  0.04337   9.43

# %%
X= np.array(df_binary['crime']).reshape(-1,1)
y = np.array(df_binary['stat']).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=1/3,random_state=0)

# %%
X_train
# Out:
# array([[7.97800e-02],
#        [3.69695e+00],
#        [1.77800e-02],
#        [1.71200e-01],
#        [3.41090e-01],
#        [2.14090e-01],
#        [1.50234e+01],
#        [8.01400e-02],
#        [2.01019e+00],
#        [1.43900e-02],
#        [6.79208e+01],
#        [5.36000e-02],
#        [8.22100e-02],
#        [1.26500e-01],
#        [4.56000e-02],
#        [7.05042e+00],
#        [4.15292e+01],
#        [1.44550e-01],
#        [2.63548e+00],
#        [1.31580e-01],
#        [3.76800e-02],
#        [1.49632e+00],
#        [4.07710e-01],
#        [7.02259e+00],
#        [2.89550e-01],
#        [8.24400e-02],
#        [4.59000e-02],
#        [1.22690e-01],
#        [6.90500e-02],
#        [3.18270e-01],
#        [6.53876e+00],
#        [9.74400e-02],
#        [3.83518e+01],
#        [1.12658e+00],
#        [3.70500e-02],
#        [5.40500e-01],
#        [8.24809e+00],
#        [2.00849e+01],
#        [6.71800e-01],
#        [1.32620e-01],
#        [5.18800e-02],
# ...

# %%
X_test
# Out:
# array([[5.11358e+01],
#        [1.04690e-01],
#        [1.78667e+01],
#        [6.21100e-02],
#        [5.09017e+00],
#        [1.74460e-01],
#        [9.26600e-02],
#        [1.68118e+01],
#        [5.75290e-01],
#        [6.58800e-02],
#        [1.48660e-01],
#        [7.85700e-01],
#        [4.02020e-01],
#        [4.52700e-02],
#        [1.00245e+00],
#        [5.78000e-02],
#        [2.72900e-02],
#        [1.52880e+01],
#        [4.41780e-01],
#        [3.30600e-02],
#        [3.55100e-02],
#        [3.11300e-02],
#        [1.17470e-01],
#        [1.40507e+01],
#        [9.59571e+00],
#        [9.06500e-02],
#        [8.15174e+00],
#        [1.20742e+00],
#        [5.70818e+00],
#        [2.89900e-02],
#        [7.99248e+00],
#        [4.42228e+00],
#        [4.54400e-02],
#        [7.50300e-02],
#        [4.47910e-01],
#        [3.93200e-02],
#        [5.42500e-02],
#        [1.36000e-02],
#        [7.01300e-02],
#        [3.15330e-01],
#        [6.61700e-02],
# ...

# %%
y_train
# Out:
# array([[ 7.19],
#        [14.  ],
#        [ 4.45],
#        [18.66],
#        [ 6.12],
#        [ 3.59],
#        [24.91],
#        [ 8.77],
#        [ 3.7 ],
#        [ 4.38],
#        [22.98],
#        [ 5.28],
#        [ 3.53],
#        [ 9.5 ],
#        [13.51],
#        [23.29],
#        [27.38],
#        [19.15],
#        [12.64],
#        [12.04],
#        [ 6.62],
#        [13.28],
#        [21.46],
#        [15.7 ],
#        [29.55],
#        [ 6.36],
#        [ 7.6 ],
#        [ 9.55],
#        [ 5.33],
#        [18.33],
#        [ 2.96],
#        [11.41],
#        [30.59],
#        [12.12],
#        [ 4.59],
#        [ 3.16],
#        [16.74],
#        [30.63],
#        [23.98],
#        [16.47],
#        [12.86],
#        [14.7 ],
#        [ 4.08],
#        [ 4.59],
#        [ 5.81],
#        [16.29],
#        [ 5.98],
#        [10.16],
#        [11.38],
#        [12.27],
#        [ 9.51],
#        [10.58],
#        [20.45],
#        [17.16],
#        [ 7.79],
# ...

# %%
y_test
# Out:
# array([[10.11],
#        [ 6.05],
#        [21.78],
#        [ 5.98],
#        [17.27],
#        [17.27],
#        [ 8.67],
#        [30.81],
#        [ 2.47],
#        [ 7.56],
#        [ 9.42],
#        [14.79],
#        [10.36],
#        [ 9.08],
#        [11.98],
#        [ 5.04],
#        [ 4.03],
#        [23.24],
#        [ 3.76],
#        [ 8.51],
#        [ 7.51],
#        [10.53],
#        [13.27],
#        [21.22],
#        [20.31],
#        [13.65],
#        [20.85],
#        [14.43],
#        [ 7.74],
#        [ 5.89],
#        [24.56],
#        [21.32],
#        [ 9.09],
#        [ 6.47],
#        [ 8.05],
#        [ 8.2 ],
#        [ 6.29],
#        [14.8 ],
#        [ 9.69],
#        [ 4.14],
#        [ 9.97],
#        [ 5.99],
#        [17.28],
#        [26.82],
#        [ 6.56],
#        [ 9.22],
#        [ 6.53],
#        [ 8.47],
#        [10.26],
#        [19.37],
#        [23.97],
#        [12.92],
#        [ 9.1 ],
#        [29.29],
#        [12.03],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.score(X_test,y_test))
# Out:
# 0.14501860276867684

# %%
y_pred=regressor.predict(X_test)
x_pred=regressor.predict(X_train)

# %%
y_pred
# Out:
# array([[26.52936619],
#        [11.18565197],
#        [16.52622178],
#        [11.17284929],
#        [12.68465484],
#        [11.20662998],
#        [11.18203487],
#        [16.20904106],
#        [11.32714903],
#        [11.17398283],
#        [11.1988726 ],
#        [11.39041379],
#        [11.27505129],
#        [11.16778594],
#        [11.45558482],
#        [11.17155338],
#        [11.16237983],
#        [15.75087443],
#        [11.28700608],
#        [11.16411471],
#        [11.16485136],
#        [11.16353441],
#        [11.18949458],
#        [15.37885083],
#        [14.03935236],
#        [11.18143051],
#        [13.60518852],
#        [11.51721392],
#        [12.87047422],
#        [11.16289097],
#        [13.55730322],
#        [12.48383787],
#        [11.16783705],
#        [11.17673399],
#        [11.28884921],
#        [11.16599693],
#        [11.17048599],
#        [11.1582636 ],
#        [11.17526069],
#        [11.24898589],
#        [11.17407002],
# ...

# %%
x_pred
# Out:
# array([[11.17816219],
#        [12.26575019],
#        [11.15952042],
#        [11.20564978],
#        [11.25673124],
#        [11.21854568],
#        [15.67131616],
#        [11.17827043],
#        [11.75858577],
#        [11.15850114],
#        [31.57617476],
#        [11.17029055],
#        [11.17889283],
#        [11.19220967],
#        [11.16788516],
#        [13.27405052],
#        [23.64091393],
#        [11.19763683],
#        [11.94659404],
#        [11.19373709],
#        [11.16550383],
#        [11.60407856],
#        [11.27676213],
#        [13.26568277],
#        [11.24123452],
#        [11.17896198],
#        [11.16797536],
#        [11.1910641 ],
#        [11.17493596],
#        [11.24986987],
#        [13.1202078 ],
#        [11.18347209],
#        [22.68555322],
#        [11.49290745],
#        [11.1653144 ],
#        [11.31668859],
#        [13.63415843],
#        [17.19317625],
#        [11.35616705],
#        [11.19404979],
#        [11.16977339],
# ...

# %%
mp.scatter(X_train,y_train,color="violet")
mp.plot(X_train,x_pred,color="black")
mp.title("Training dataset")
mp.xlabel("crim")
mp.ylabel("stat")
mp.show()

# %%
mp.scatter(X_train,y_train,color="yellow")
mp.plot(X_train,x_pred,color="blue")
mp.title("Testing dataset")
mp.xlabel("crim")
mp.ylabel("stat")
mp.show()

# %%
print(regressor.score(X_test,y_test))
# Out:
# 0.14501860276867684

# %%
print(regressor.score(X_train,y_train))
# Out:
# 0.19795110910857416

# %%
print(regressor.score(X_train,x_pred))
# Out:
# 1.0

# %%
print(regressor.score(X_test,y_pred))
# Out:
# 1.0

# %%
print(regressor.score())
